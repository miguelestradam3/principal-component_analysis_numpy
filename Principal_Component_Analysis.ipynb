# %% [markdown]
# <h2 align=center> Principal Component Analysis</h2>

# %% [markdown]
# ### Task 2: Load the Data and Libraries
# ---

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.style.use("ggplot")
plt.rcParams["figure.figsize"] = (12,8)

# %%
# data URL: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
iris = pd.read_csv('iris.data', header=None)
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.columns = ['sepal_lenght', 'sepal_width', 'petal_lenght', 'petal_width', 'species']
iris.dropna(how='all', inplace=True)
iris.head()
# Out:
#    sepal_lenght  sepal_width  petal_lenght  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_lenght  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_lenght  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Task 3: Visualize the Data
# ---

# %%
sns.scatterplot(x=iris.sepal_lenght, y=iris.sepal_width, hue=iris.species, style=iris.species)
# Out:
# <Axes: xlabel='sepal_lenght', ylabel='sepal_width'>

# %% [markdown]
# ### Task 4: Standardize the Data
# ---

# %%
X = iris.iloc[:, 0:4].values
y = iris.species.values

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Task 5: Compute the Eigenvectors and Eigenvalues
# ---

# %% [markdown]
# Covariance: $\sigma_{jk} = \frac{1}{n-1}\sum_{i=1}^{N}(x_{ij}-\bar{x_j})(x_{ik}-\bar{x_k})$
#
# Coviance matrix: $Σ = \frac{1}{n-1}((X-\bar{x})^T(X-\bar{x}))$

# %%
covariance_matrix = np.cov(X.T)
print("\nCovariance matrix: ", covariance_matrix)
# Out:
# Covariance matrix:  [[ 1.00671141 -0.11010327  0.87760486  0.82344326]
#  [-0.11010327  1.00671141 -0.42333835 -0.358937  ]
#  [ 0.87760486 -0.42333835  1.00671141  0.96921855]
#  [ 0.82344326 -0.358937    0.96921855  1.00671141]]

# %% [markdown]
# We can prove this by looking at the covariance matrix. It has the property that it is symmetric. We also constrain the each of the columns (eigenvectors) such that the values sum to one. Thus, they are orthonormal to each other.
#
# Eigendecomposition of the covriance matrix:  $Σ = W\wedge W^{-1}$

# %%
eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)
print("Eigen vectors\n", eigen_vectors)
print("Eigen values\n", eigen_values)
# Out:
# Eigen vectors
#  [[ 0.52237162 -0.37231836 -0.72101681  0.26199559]
#  [-0.26335492 -0.92555649  0.24203288 -0.12413481]
#  [ 0.58125401 -0.02109478  0.14089226 -0.80115427]
#  [ 0.56561105 -0.06541577  0.6338014   0.52354627]]
# Eigen values
#  [2.93035378 0.92740362 0.14834223 0.02074601]

# %% [markdown]
# ### Task 6: Singular Value Decomposition (SVD)
# ---

# %%
eigen_vec_svd = np.linalg.svd(X.T)
eigen_vec_svd
# Out:
# SVDResult(U=array([[-0.52237162, -0.37231836,  0.72101681,  0.26199559],
#        [ 0.26335492, -0.92555649, -0.24203288, -0.12413481],
#        [-0.58125401, -0.02109478, -0.14089226, -0.80115427],
#        [-0.56561105, -0.06541577, -0.6338014 ,  0.52354627]]), S=array([20.89551896, 11.75513248,  4.7013819 ,  1.75816839]), Vh=array([[ 1.08374515e-01,  9.98503796e-02,  1.13323362e-01, ...,
#         -7.27833114e-02, -6.58701606e-02, -4.59092965e-02],
#        [-4.30198387e-02,  5.57547718e-02,  2.70926177e-02, ...,
#         -2.26960075e-02, -8.64611208e-02,  1.89567788e-03],
#        [ 2.59377669e-02,  4.83370288e-02, -1.09498919e-02, ...,
#         -3.81328738e-02, -1.98113038e-01, -1.12476331e-01],
#        ...,
#        [ 5.42576376e-02,  5.32189412e-03,  2.76010922e-02, ...,
#          9.89545817e-01, -1.40226565e-02, -7.86338250e-04],
#        [ 1.60581494e-03,  8.56651825e-02,  1.78415121e-01, ...,
#         -1.24233079e-02,  9.52228601e-01, -2.19591161e-02],
#        [ 2.27770498e-03,  6.44405862e-03,  1.49430370e-01, ...,
#         -6.58105858e-04, -2.32385318e-02,  9.77215825e-01]]))

# %% [markdown]
# ### Task 7: Picking Principal Components Using the Explained Variance
# ---

# %%
for val in eigen_values:
    print(val)
# Out:
# 2.9303537755893165
# 0.9274036215173417
# 0.14834222648163994
# 0.020746013995596356

# %%
variance_explained = [i/sum(eigen_values)*100 for i in eigen_values]
variance_explained
# Out:
# [np.float64(72.77045209380132),
#  np.float64(23.03052326768064),
#  np.float64(3.68383195762739),
#  np.float64(0.5151926808906425)]

# %%
cumulative_variance_explained = np.cumsum(variance_explained)
cumulative_variance_explained
# Out:
# array([ 72.77045209,  95.80097536,  99.48480732, 100.        ])

# %%
sns.lineplot(x=[1, 2, 3, 4], y=cumulative_variance_explained)
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance")
plt.title("Explained variance vs. Number of components")
# Out:
# Text(0.5, 1.0, 'Explained variance vs. Number of components')

# %% [markdown]
# ### Task 8: Project Data Onto Lower-Dimensional Linear Subspace
# ---

# %%
eigen_vectors
# Out:
# array([[ 0.52237162, -0.37231836, -0.72101681,  0.26199559],
#        [-0.26335492, -0.92555649,  0.24203288, -0.12413481],
#        [ 0.58125401, -0.02109478,  0.14089226, -0.80115427],
#        [ 0.56561105, -0.06541577,  0.6338014 ,  0.52354627]])

# %%
projection_matrix = (eigen_vectors.T[:][:])[:2].T
print("Projection matrix: \n", projection_matrix)
# Out:
# Projection matrix:
#  [[ 0.52237162 -0.37231836]
#  [-0.26335492 -0.92555649]
#  [ 0.58125401 -0.02109478]
#  [ 0.56561105 -0.06541577]]

# %%
X_pca = X.dot(projection_matrix)

# %%
for species in ('Iris-setosa', 'Iris-versicolor', 'Iris-virginica'):
    sns.scatterplot(x=X_pca[y==species, 0], y=X_pca[y==species, 1])
